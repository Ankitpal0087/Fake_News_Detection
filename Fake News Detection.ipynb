# %%
import pandas as pd
import numpy as np
import nltk

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
import pandas as pd
import numpy as np
import nltk

from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
fake = pd.read_csv("dataset/Fake.csv")
true = pd.read_csv("dataset/True.csv")

# %%
fake.head()
# Out:
#                                                title  \
# 0  Donald Trump Sends Out Embarrassing New Year’s...
# 1  Drunk Bragging Trump Staffer Started Russian C...
# 2  Sheriff David Clarke Becomes An Internet Joke ...
# 3  Trump Is So Obsessed He Even Has Obama’s Name ...
# 4  Pope Francis Just Called Out Donald Trump Duri...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                 date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake["classes"]=0
true["classes"]=1

# %%
fake.tail()
# Out:
#                                                    title  \
# 13834  ILLEGAL ALIENS Sent To States With Lax Voter I...
# 13835  BREAKING! INVESTIGATION: Hillary Clinton Did N...
# 13836  DEMOCRAT UNDERBELLY EXPOSED: Out-Of-Control Vi...
# 13837  DESPERATION OR STUPIDITY? GERMAN State Recruit...
# 13838  WATCH: Black Lives Matter Terrorists CRASH Sta...
#
#                                                     text   subject  \
# 13834  DEMOCRATS Making free and fair elections impos...  politics
# 13835   Was Hillary Clinton negligent or was she doin...  politics
# 13836  Donald Trump on Wednesday slammed what he desc...  politics
# 13837  It s too late for these countries who ve been ...  politics
# 13838  It s hard to tell what these Black Lives Matte...  politics
#
#                date  classes
# 13834  May 25, 2016        0
# 13835  May 25, 2016        0
# 13836  May 25, 2016        0
# 13837  May 25, 2016        0
# 13838  May 25, 2016        0

# %%
true.tail()
# Out:
#                                                   title  \
# 6744  Green Party U.S. election recount bid comes to...
# 6745  China warns Trump against ignoring its Taiwan ...
# 6746  Trump attack on Lockheed Martin foreshadows wa...
# 6747  Senate Republican leader backs investigation i...
# 6748  Trump taps Goldman Sachs executive Cohn for ke...
#
#                                                    text       subject  \
# 6744  (Reuters) - The recount effort by Green Party ...  politicsNews
# 6745  BEIJING (Reuters) - China expressed “serious c...  politicsNews
# 6746  SEATTLE (Reuters) - Donald Trump on Monday wid...  politicsNews
# 6747  WASHINGTON (Reuters) - The Senate’s top Republ...  politicsNews
# 6748  WASHINGTON (Reuters) - U.S. President-elect Do...  politicsNews
#
#                    date  classes
# 6744  December 12, 2016        1
# 6745  December 12, 2016        1
# 6746  December 12, 2016        1
# 6747  December 12, 2016        1
# 6748  December 12, 2016        1

# %%
data=pd.concat([fake,true],axis=0)

# %%
data = data.sample(frac=1)

# %%
data.reset_index(inplace=True)

# %%
data.drop(["index"],axis=1,inplace=True)

# %%
data.head()
# Out:
#                                                title  \
# 0  Another White Guy Goes On A Shooting Spree And...
# 1  Trump may not enforce individual health insura...
# 2  GOP Puts Together Secret Talking Points To Def...
# 3  U.S. attorney general calls for efficient revi...
# 4  Obama says he would have outrun Trump, but Tru...
#
#                                                 text       subject  \
# 0  Six people are dead after a white, domestic te...          News
# 1  WASHINGTON (Reuters) - The Trump administratio...  politicsNews
# 2  The Trump White House is perhaps the leakiest ...          News
# 3  WASHINGTON (Reuters) - U.S. Attorney General J...  politicsNews
# 4  HONOLULU (Reuters) - U.S. President Barack Oba...  politicsNews
#
#                 date  classes
# 0  February 21, 2016        0
# 1   January 22, 2017        1
# 2      June 15, 2017        0
# 3   December 6, 2017        1
# 4  December 27, 2016        1

# %%
data.shape
# Out:
# (20588, 5)

# %%
data.isnull().sum()
# Out:
# title        0
# text       371
# subject      0
# date         0
# classes      0
# dtype: int64

# %%
data.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'classes'], dtype='object')

# %%
data = data.drop(["title", "subject", "date"], axis=1)

# %%
data.head()
# Out:
#                                                 text  classes
# 0  Six people are dead after a white, domestic te...        0
# 1  WASHINGTON (Reuters) - The Trump administratio...        1
# 2  The Trump White House is perhaps the leakiest ...        0
# 3  WASHINGTON (Reuters) - U.S. Attorney General J...        1
# 4  HONOLULU (Reuters) - U.S. President Barack Oba...        1

# %%
import re 
import string

# %%
def wordopt(text):
    text = text.lower()
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'https?://\S+|www\.\S+', '', text)
    text = re.sub(r'<.*?>+', '', text)
    text = re.sub(r'[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub(r'\n', '', text)
    text = re.sub(r'\w*\d\w*', '', text)
    return text

# %%
data= data.dropna()

# %%
data["text"] = data["text"].apply(wordopt)

# %%
data.head()
# Out:
#                                                 text  classes
# 0  six people are dead after a white domestic ter...        0
# 1  washington reuters  the trump administration m...        1
# 2  the trump white house is perhaps the leakiest ...        0
# 3  washington reuters  us attorney general jeff s...        1
# 4  honolulu reuters  us president barack obama sa...        1

# %%
x = data["text"]
y = data["classes"]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.25, random_state=42
)

# %%
vectorization = TfidfVectorizer()
xv_train = vectorization.fit_transform(x_train)
xv_test = vectorization.transform(x_test)

# %%
LR = LogisticRegression()
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
pred_lr = LR.predict(xv_test)

# %%
accuracy_score(y_test,pred_lr)
# Out:
# 0.9798219584569733

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      3404
#            1       0.98      0.96      0.97      1651
#
#     accuracy                           0.98      5055
#    macro avg       0.98      0.98      0.98      5055
# weighted avg       0.98      0.98      0.98      5055

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, pred_lr))
# Out:
# [[3366   38]
#  [  64 1587]]

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, pred_lr))
# Out:
# [[3366   38]
#  [  64 1587]]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
DT  = DecisionTreeClassifier()
DT.fit(xv_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt = DT.predict(xv_test)

# %%
accuracy_score(y_test,pred_dt)
# Out:
# 0.9972304648862512

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
RF = RandomForestClassifier(random_state=42)
RF.fit(xv_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pred_rf = RF.predict(xv_test)

# %%
accuracy_score(y_test,pred_rf)
# Out:
# 0.9780415430267062

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GB = GradientBoostingClassifier(random_state=42)
GB.fit(xv_train, y_train)
# Out:
# GradientBoostingClassifier(random_state=42)

# %%
pred_gb = GB.predict(xv_test)

# %%
def manual_testing(news):

    testing_news = {"text": [news]}
    new_def_test = pd.DataFrame(testing_news)

    new_def_test["text"] = new_def_test["text"].apply(wordopt)

    new_x_test = vectorization.transform(new_def_test["text"])

    pred_LR = LR.predict(new_x_test)

    return output_label(pred_LR[0])

# %%
news = str(input())
manual_testing(news)

# %%
import pickle

pickle.dump(LR, open("model/logistic_model.pkl", "wb"))
pickle.dump(vectorization, open("model/vectorizer.pkl", "wb"))

# %%
import os 
os.listdir("model")
# Out:
# ['logistic_model.pkl', 'vectorizer.pkl']
